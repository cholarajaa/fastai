# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
from fastai.conv_learner import *
from fastai.dataset import *

from pathlib import Path
import json

# %% [markdown]
# ## Data

# %% [markdown]
# ### Setup

# %%
PATH = Path('data/carvana')
list(PATH.iterdir())
# Out:
# [PosixPath('data/carvana/train.zip'),
#  PosixPath('data/carvana/sample_submission.csv'),
#  PosixPath('data/carvana/train_masks.csv'),
#  PosixPath('data/carvana/train_masks_png'),
#  PosixPath('data/carvana/train_masks-128'),
#  PosixPath('data/carvana/test'),
#  PosixPath('data/carvana/train_masks.csv.zip'),
#  PosixPath('data/carvana/29bb3ece3180_11.jpg'),
#  PosixPath('data/carvana/metadata.csv'),
#  PosixPath('data/carvana/train_hq'),
#  PosixPath('data/carvana/sample_submission.csv.zip'),
#  PosixPath('data/carvana/train-128'),
#  PosixPath('data/carvana/train_hq.zip'),
#  PosixPath('data/carvana/test_hq.zip'),
#  PosixPath('data/carvana/train_masks.zip'),
#  PosixPath('data/carvana/models'),
#  PosixPath('data/carvana/train_masks'),
#  PosixPath('data/carvana/train'),
#  PosixPath('data/carvana/metadata.csv.zip'),
#  PosixPath('data/carvana/tmp'),
#  PosixPath('data/carvana/test.zip')]

# %%
MASKS_FN = 'train_masks.csv'
META_FN = 'metadata.csv'
TRAIN_DN = 'train'
MASKS_DN = 'train_masks'

# %%
masks_csv = pd.read_csv(PATH/MASKS_FN)
masks_csv.head()
# Out:
#                    img                                           rle_mask
# 0  00087a6bd4dc_01.jpg  879386 40 881253 141 883140 205 885009 17 8850...
# 1  00087a6bd4dc_02.jpg  873779 4 875695 7 877612 9 879528 12 881267 15...
# 2  00087a6bd4dc_03.jpg  864300 9 866217 13 868134 15 870051 16 871969 ...
# 3  00087a6bd4dc_04.jpg  879735 20 881650 26 883315 92 883564 30 885208...
# 4  00087a6bd4dc_05.jpg  883365 74 883638 28 885262 119 885550 34 88716...

# %%
meta_csv = pd.read_csv(PATH/META_FN)
meta_csv.head()
# Out:
#              id    year       make   model   trim1                    trim2
# 0  0004d4463b50  2014.0      Acura      TL      TL                     w/SE
# 1  00087a6bd4dc  2014.0      Acura     RLX     RLX                   w/Tech
# 2  000aa097d423  2012.0      Mazda  MAZDA6  MAZDA6                  i Sport
# 3  000f19f6e7d4  2016.0  Chevrolet  Camaro  Camaro                       SS
# 4  00144e887ae9  2015.0      Acura     TLX     TLX  SH-AWD V6 w/Advance Pkg

# %%
def show_img(im, figsize=None, ax=None, alpha=None):
    if not ax: fig,ax = plt.subplots(figsize=figsize)
    ax.imshow(im, alpha=alpha)
    ax.set_axis_off()
    return ax

# %%
CAR_ID = '00087a6bd4dc'

# %%
list((PATH/TRAIN_DN).iterdir())[:5]
# Out:
# [PosixPath('data/carvana/train/b58cc561e560_01.jpg'),
#  PosixPath('data/carvana/train/6343156803f9_16.jpg'),
#  PosixPath('data/carvana/train/d9b2ded58b72_14.jpg'),
#  PosixPath('data/carvana/train/7ac210ba75a1_02.jpg'),
#  PosixPath('data/carvana/train/1c5748340af8_01.jpg')]

# %%
Image.open(PATH/TRAIN_DN/f'{CAR_ID}_01.jpg').resize((300,200))
# Out:
# <PIL.Image.Image image mode=RGB size=300x200 at 0x7FB73270B7F0>

# %%
list((PATH/MASKS_DN).iterdir())[:5]
# Out:
# [PosixPath('data/carvana/train_masks/e5fc2c1c4a8b_06_mask.gif'),
#  PosixPath('data/carvana/train_masks/2a4a8964ebf3_11_mask.gif'),
#  PosixPath('data/carvana/train_masks/b44091aa62e4_13_mask.gif'),
#  PosixPath('data/carvana/train_masks/d1a3af34e674_10_mask.gif'),
#  PosixPath('data/carvana/train_masks/245f9c9eab8a_03_mask.gif')]

# %%
Image.open(PATH/MASKS_DN/f'{CAR_ID}_01_mask.gif').resize((300,200))
# Out:
# <PIL.Image.Image image mode=P size=300x200 at 0x7FB6B126A128>

# %%
ims = [open_image(PATH/TRAIN_DN/f'{CAR_ID}_{i+1:02d}.jpg') for i in range(16)]

# %%
fig, axes = plt.subplots(4, 4, figsize=(9, 6))
for i,ax in enumerate(axes.flat): show_img(ims[i], ax=ax)
plt.tight_layout(pad=0.1)

# %% [markdown]
# ### Resize and convert

# %%
(PATH/'train_masks_png').mkdir(exist_ok=True)

# %%
def convert_img(fn):
    fn = fn.name
    Image.open(PATH/'train_masks'/fn).save(PATH/'train_masks_png'/f'{fn[:-4]}.png')

# %%
files = list((PATH/'train_masks').iterdir())
with ThreadPoolExecutor(8) as e: e.map(convert_img, files)

# %%
(PATH/'train_masks-128').mkdir(exist_ok=True)

# %%
def resize_mask(fn):
    Image.open(fn).resize((128,128)).save((fn.parent.parent)/'train_masks-128'/fn.name)

files = list((PATH/'train_masks_png').iterdir())
with ThreadPoolExecutor(8) as e: e.map(resize_mask, files)

# %%
(PATH/'train-128').mkdir(exist_ok=True)

# %%
def resize_img(fn):
    Image.open(fn).resize((128,128)).save((fn.parent.parent)/'train-128'/fn.name)

files = list((PATH/'train').iterdir())
with ThreadPoolExecutor(8) as e: e.map(resize_img, files)

# %% [markdown]
# ## Dataset

# %%
TRAIN_DN = 'train-128'
MASKS_DN = 'train_masks-128'
sz = 128
bs = 64

# %%
ims = [open_image(PATH/TRAIN_DN/f'{CAR_ID}_{i+1:02d}.jpg') for i in range(16)]
im_masks = [open_image(PATH/MASKS_DN/f'{CAR_ID}_{i+1:02d}_mask.png') for i in range(16)]

# %%
fig, axes = plt.subplots(4, 4, figsize=(9, 6))
for i,ax in enumerate(axes.flat):
    ax = show_img(ims[i], ax=ax)
    show_img(im_masks[i][...,0], ax=ax, alpha=0.5)
plt.tight_layout(pad=0.1)

# %%
class MatchedFilesDataset(FilesDataset):
    def __init__(self, fnames, y, transform, path):
        self.y=y
        assert(len(fnames)==len(y))
        super().__init__(fnames, transform, path)
    def get_y(self, i): return open_image(os.path.join(self.path, self.y[i]))
    
    def denorm(self,arr):
        """Reverse the normalization done to a batch of images.

        Arguments:
            arr: of shape/size (N,3,sz,sz)
        """
#         print('Denorm called')
        if type(arr) is not np.ndarray: arr = to_np(arr)
        if len(arr.shape)==3: arr = arr[None]
        return self.transform.denorm(np.rollaxis(arr,1,4))
    
    def get_c(self): 
#         print(self.y.shape) 
        return 0

# %%
x_names = np.array([Path(TRAIN_DN)/o for o in masks_csv['img']])
y_names = np.array([Path(MASKS_DN)/f'{o[:-4]}_mask.png' for o in masks_csv['img']])

# %%
len(x_names)//16//5*16
# Out:
# 1008

# %%
val_idxs = list(range(1008))
((val_x,trn_x),(val_y,trn_y)) = split_by_idx(val_idxs, x_names, y_names)
len(val_x),len(trn_x)
# Out:
# (1008, 4080)

# %%
aug_tfms = [RandomRotate(4, tfm_y=TfmType.PIXEL),
            RandomFlip(tfm_y=TfmType.PIXEL),
            RandomLighting(0.05, 0.05)]
# aug_tfms = []

# %%
tfms = tfms_from_model(vgg16, sz, crop_type=CropType.NO, tfm_y=TfmType.NO, aug_tfms=aug_tfms)
datasets = ImageData.get_ds(MatchedFilesDataset, (trn_x,trn_y), (val_x,val_y), tfms, path=PATH)
md = ImageData(PATH, datasets, bs, num_workers=8, classes=None)

# %%
denorm = md.trn_ds.denorm
x,y = next(iter(md.aug_dl))
x = denorm(x)
y_d = denorm(y)

# %%
fig, axes = plt.subplots(5, 6, figsize=(12, 10))
for i,ax in enumerate(axes.flat):
    ax=show_img(x[i], ax=ax)
    show_img(y_d[i][...,0], ax=ax, alpha=0.5)
plt.tight_layout(pad=0.1)

# %%
np.average(y[0, :, :, 0] == y[0, :, :, 2])
# Out:
# 1.0

# %%
x1,y1 = next(iter(md.trn_dl))

# %% [markdown]
# ## Model

# %%
class Empty(nn.Module): 
    def forward(self,x): return x

models = ConvnetBuilder(vgg16, 0, 0, 0, custom_head=Empty())
learn = ConvLearner(md, models)
learn.summary()
# Out:
# OrderedDict([('Conv2d-1',
#               OrderedDict([('input_shape', [-1, 3, 128, 128]),
#                            ('output_shape', [-1, 64, 128, 128]),
#                            ('trainable', False),
#                            ('nb_params', 1792)])),
#              ('BatchNorm2d-2',
#               OrderedDict([('input_shape', [-1, 64, 128, 128]),
#                            ('output_shape', [-1, 64, 128, 128]),
#                            ('trainable', False),
#                            ('nb_params', 128)])),
#              ('ReLU-3',
#               OrderedDict([('input_shape', [-1, 64, 128, 128]),
#                            ('output_shape', [-1, 64, 128, 128]),
#                            ('nb_params', 0)])),
#              ('Conv2d-4',
#               OrderedDict([('input_shape', [-1, 64, 128, 128]),
#                            ('output_shape', [-1, 64, 128, 128]),
#                            ('trainable', False),
#                            ('nb_params', 36928)])),
#              ('BatchNorm2d-5',
#               OrderedDict([('input_shape', [-1, 64, 128, 128]),
#                            ('output_shape', [-1, 64, 128, 128]),
#                            ('trainable', False),
#                            ('nb_params', 128)])),
#              ('ReLU-6',
#               OrderedDict([('input_shape', [-1, 64, 128, 128]),
#                            ('output_shape', [-1, 64, 128, 128]),
#                            ('nb_params', 0)])),
#              ('MaxPool2d-7',
#               OrderedDict([('input_shape', [-1, 64, 128, 128]),
#                            ('output_shape', [-1, 64, 64, 64]),
#                            ('nb_params', 0)])),
#              ('Conv2d-8',
#               OrderedDict([('input_shape', [-1, 64, 64, 64]),
#                            ('output_shape', [-1, 128, 64, 64]),
#                            ('trainable', False),
#                            ('nb_params', 73856)])),
#              ('BatchNorm2d-9',
#               OrderedDict([('input_shape', [-1, 128, 64, 64]),
#                            ('output_shape', [-1, 128, 64, 64]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-10',
#               OrderedDict([('input_shape', [-1, 128, 64, 64]),
#                            ('output_shape', [-1, 128, 64, 64]),
#                            ('nb_params', 0)])),
#              ('Conv2d-11',
#               OrderedDict([('input_shape', [-1, 128, 64, 64]),
#                            ('output_shape', [-1, 128, 64, 64]),
#                            ('trainable', False),
#                            ('nb_params', 147584)])),
#              ('BatchNorm2d-12',
#               OrderedDict([('input_shape', [-1, 128, 64, 64]),
#                            ('output_shape', [-1, 128, 64, 64]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-13',
#               OrderedDict([('input_shape', [-1, 128, 64, 64]),
#                            ('output_shape', [-1, 128, 64, 64]),
#                            ('nb_params', 0)])),
#              ('MaxPool2d-14',
#               OrderedDict([('input_shape', [-1, 128, 64, 64]),
#                            ('output_shape', [-1, 128, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-15',
#               OrderedDict([('input_shape', [-1, 128, 32, 32]),
#                            ('output_shape', [-1, 256, 32, 32]),
#                            ('trainable', False),
#                            ('nb_params', 295168)])),
#              ('BatchNorm2d-16',
#               OrderedDict([('input_shape', [-1, 256, 32, 32]),
#                            ('output_shape', [-1, 256, 32, 32]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-17',
#               OrderedDict([('input_shape', [-1, 256, 32, 32]),
#                            ('output_shape', [-1, 256, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-18',
#               OrderedDict([('input_shape', [-1, 256, 32, 32]),
#                            ('output_shape', [-1, 256, 32, 32]),
#                            ('trainable', False),
#                            ('nb_params', 590080)])),
#              ('BatchNorm2d-19',
#               OrderedDict([('input_shape', [-1, 256, 32, 32]),
#                            ('output_shape', [-1, 256, 32, 32]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-20',
#               OrderedDict([('input_shape', [-1, 256, 32, 32]),
#                            ('output_shape', [-1, 256, 32, 32]),
#                            ('nb_params', 0)])),
#              ('Conv2d-21',
#               OrderedDict([('input_shape', [-1, 256, 32, 32]),
#                            ('output_shape', [-1, 256, 32, 32]),
#                            ('trainable', False),
#                            ('nb_params', 590080)])),
#              ('BatchNorm2d-22',
#               OrderedDict([('input_shape', [-1, 256, 32, 32]),
#                            ('output_shape', [-1, 256, 32, 32]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-23',
#               OrderedDict([('input_shape', [-1, 256, 32, 32]),
#                            ('output_shape', [-1, 256, 32, 32]),
#                            ('nb_params', 0)])),
#              ('MaxPool2d-24',
#               OrderedDict([('input_shape', [-1, 256, 32, 32]),
#                            ('output_shape', [-1, 256, 16, 16]),
#                            ('nb_params', 0)])),
#              ('Conv2d-25',
#               OrderedDict([('input_shape', [-1, 256, 16, 16]),
#                            ('output_shape', [-1, 512, 16, 16]),
#                            ('trainable', False),
#                            ('nb_params', 1180160)])),
#              ('BatchNorm2d-26',
#               OrderedDict([('input_shape', [-1, 512, 16, 16]),
#                            ('output_shape', [-1, 512, 16, 16]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-27',
#               OrderedDict([('input_shape', [-1, 512, 16, 16]),
#                            ('output_shape', [-1, 512, 16, 16]),
#                            ('nb_params', 0)])),
#              ('Conv2d-28',
#               OrderedDict([('input_shape', [-1, 512, 16, 16]),
#                            ('output_shape', [-1, 512, 16, 16]),
#                            ('trainable', False),
#                            ('nb_params', 2359808)])),
#              ('BatchNorm2d-29',
#               OrderedDict([('input_shape', [-1, 512, 16, 16]),
#                            ('output_shape', [-1, 512, 16, 16]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-30',
#               OrderedDict([('input_shape', [-1, 512, 16, 16]),
#                            ('output_shape', [-1, 512, 16, 16]),
#                            ('nb_params', 0)])),
#              ('Conv2d-31',
#               OrderedDict([('input_shape', [-1, 512, 16, 16]),
#                            ('output_shape', [-1, 512, 16, 16]),
#                            ('trainable', False),
#                            ('nb_params', 2359808)])),
#              ('BatchNorm2d-32',
#               OrderedDict([('input_shape', [-1, 512, 16, 16]),
#                            ('output_shape', [-1, 512, 16, 16]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-33',
#               OrderedDict([('input_shape', [-1, 512, 16, 16]),
#                            ('output_shape', [-1, 512, 16, 16]),
#                            ('nb_params', 0)])),
#              ('MaxPool2d-34',
#               OrderedDict([('input_shape', [-1, 512, 16, 16]),
#                            ('output_shape', [-1, 512, 8, 8]),
#                            ('nb_params', 0)])),
#              ('Conv2d-35',
#               OrderedDict([('input_shape', [-1, 512, 8, 8]),
#                            ('output_shape', [-1, 512, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 2359808)])),
#              ('BatchNorm2d-36',
#               OrderedDict([('input_shape', [-1, 512, 8, 8]),
#                            ('output_shape', [-1, 512, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-37',
#               OrderedDict([('input_shape', [-1, 512, 8, 8]),
#                            ('output_shape', [-1, 512, 8, 8]),
#                            ('nb_params', 0)])),
#              ('Conv2d-38',
#               OrderedDict([('input_shape', [-1, 512, 8, 8]),
#                            ('output_shape', [-1, 512, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 2359808)])),
#              ('BatchNorm2d-39',
#               OrderedDict([('input_shape', [-1, 512, 8, 8]),
#                            ('output_shape', [-1, 512, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-40',
#               OrderedDict([('input_shape', [-1, 512, 8, 8]),
#                            ('output_shape', [-1, 512, 8, 8]),
#                            ('nb_params', 0)])),
#              ('Conv2d-41',
#               OrderedDict([('input_shape', [-1, 512, 8, 8]),
#                            ('output_shape', [-1, 512, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 2359808)])),
#              ('BatchNorm2d-42',
#               OrderedDict([('input_shape', [-1, 512, 8, 8]),
#                            ('output_shape', [-1, 512, 8, 8]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-43',
#               OrderedDict([('input_shape', [-1, 512, 8, 8]),
#                            ('output_shape', [-1, 512, 8, 8]),
#                            ('nb_params', 0)])),
#              ('MaxPool2d-44',
#               OrderedDict([('input_shape', [-1, 512, 8, 8]),
#                            ('output_shape', [-1, 512, 4, 4]),
#                            ('nb_params', 0)])),
#              ('Empty-45',
#               OrderedDict([('input_shape', [-1, 512, 4, 4]),
#                            ('output_shape', [-1, 512, 4, 4]),
#                            ('nb_params', 0)]))])

# %%
class StdUpsample(nn.Module):
    def __init__(self, nin, nout):
        super().__init__()
        self.conv = nn.ConvTranspose2d(nin, nout, 2, stride=2)
        self.bn = nn.BatchNorm2d(nout)
        
    def forward(self, x): return self.bn(F.relu(self.conv(x)))

# %%
simple_up = nn.Sequential(
    nn.ReLU(),
    StdUpsample(512,256),
    StdUpsample(256,256),
    StdUpsample(256,256),
    StdUpsample(256,256),
    nn.ConvTranspose2d(256, 1, 2, stride=2)
)

# %%
def mask_loss(pred,targ):
    return F.binary_cross_entropy_with_logits(pred[:,0],targ[:,0])

def mask_acc(pred,targ): return accuracy_multi(pred[:,0], targ[:,0], 0.5)

# %%
models = ConvnetBuilder(vgg16, 0, 0, 0, custom_head=simple_up)
learn = ConvLearner(md, models)
learn.opt_fn=optim.Adam
learn.crit=mask_loss
learn.metrics=[mask_acc]

# %%
learn.lr_find()
learn.sched.plot()

# %%
lr=4e-2

# %%
learn.fit(lr,1,cycle_len=5,use_clr=(20,5))

# %%
learn.save('vgg-tmp')

# %%
learn.load('vgg-tmp')

# %%
py,ay = learn.predict_with_targs()

# %%
ay[0].shape
# Out:
# (3, 128, 128)

# %%
ay_d = denorm(ay)

# %%
ay_roll = np.rollaxis(ay, 1, 4)

# %%
plt.imshow(ay_roll[0])

# %%
show_img(py[0][0]>0);

# %%
learn.unfreeze()

# %%
learn.bn_freeze(True)

# %%
lrs = np.array([lr/100,lr/10,lr])/4

# %%
learn.fit(lrs,1,cycle_len=40,use_clr=(20,10))
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=40), HTML(value='')))
# epoch      trn_loss   val_loss   mask_acc
#     0      0.051964   0.049807   0.977932
#     1      0.043395   0.040777   0.981753
#     2      0.03766    0.036017   0.984221
#     3      0.033227   0.033637   0.985324
#     4      0.030033   0.029481   0.987776
#     5      0.02723    0.031226   0.98827
#     6      0.024756   0.025959   0.988867
#     7      0.0232     0.025393   0.988907
#     8      0.022025   0.024127   0.990018
#     9      0.021005   0.023342   0.990151
#     10     0.020333   0.02325    0.990107
#     11     0.019718   0.023057   0.990848
#     12     0.019318   0.023351   0.989444
#     13     0.01888    0.022229   0.991099
#     14     0.018265   0.021959   0.991378
#     15     0.017714   0.021571   0.991522
#     16     0.017299   0.021787   0.991248
#     17     0.017073   0.021307   0.991315
#     18     0.016698   0.0208     0.991757
#     19     0.016395   0.020331   0.991699
#     20     0.016102   0.020979   0.991805
#     21     0.015936   0.020135   0.991995
#     22     0.015602   0.020165   0.991917
#     23     0.015342   0.020653   0.99207
#     24     0.015207   0.019943   0.992016
#     25     0.014984   0.019853   0.992115
#     26     0.014747   0.019814   0.992023
#     27     0.014548   0.019685   0.992015
#     28     0.014331   0.019738   0.992241
#     29     0.014158   0.019724   0.992303
#     30     0.014001   0.019514   0.992391
#     31     0.01381    0.019247   0.992451
#     32     0.013629   0.0196     0.992603
#     33     0.013458   0.019379   0.992577
#     34     0.013279   0.019436   0.992472
#     35     0.013172   0.019067   0.992631
#     36     0.012944   0.019311   0.992721
#     37     0.012861   0.019176   0.992597
#     38     0.012734   0.019299   0.992797
#     39     0.012581   0.019224   0.992754
# [0.019224338, 0.9927540831267834]

# %%
learn.save('vgg-0')

# %%
learn.load('vgg-0')

# %%
x,y = next(iter(md.val_dl))
py = to_np(learn.model(V(x)))

# %%
ax = show_img(denorm(x)[0])
show_img(py[0][0]>0, ax=ax, alpha=0.5);

# %%
ax = show_img(denorm(x)[0])
show_img(y[0,...,-1], ax=ax, alpha=0.5);

# %% [markdown]
# ## 512x512

# %%
TRAIN_DN = 'train'
MASKS_DN = 'train_masks_png'
sz = 512
bs = 16

# %%
x_names = np.array([Path(TRAIN_DN)/o for o in masks_csv['img']])
y_names = np.array([Path(MASKS_DN)/f'{o[:-4]}_mask.png' for o in masks_csv['img']])

# %%
((val_x,trn_x),(val_y,trn_y)) = split_by_idx(val_idxs, x_names, y_names)
len(val_x),len(trn_x)
# Out:
# (1008, 4080)

# %%
tfms = tfms_from_model(vgg16, sz, crop_type=CropType.NO, tfm_y=TfmType.PIXEL, aug_tfms=aug_tfms)
datasets = ImageData.get_ds(MatchedFilesDataset, (trn_x,trn_y), (val_x,val_y), tfms, path=PATH)
md = ImageData(PATH, datasets, bs, num_workers=4, classes=None)

# %%
denorm = md.trn_ds.denorm
x,y = next(iter(md.aug_dl))
x = denorm(x)
y = denorm(y)

# %%
fig, axes = plt.subplots(4, 4, figsize=(10, 10))
for i,ax in enumerate(axes.flat):
    ax=show_img(x[i], ax=ax)
    show_img(y[i][...,0], ax=ax, alpha=0.5)
plt.tight_layout(pad=0.1)

# %%
simple_up = nn.Sequential(
    nn.ReLU(),
    StdUpsample(512,256),
    StdUpsample(256,256),
    StdUpsample(256,256),
    StdUpsample(256,256),
    nn.ConvTranspose2d(256, 1, 2, stride=2),
)

# %%
models = ConvnetBuilder(vgg16, 0, 0, 0, custom_head=simple_up)
learn = ConvLearner(md, models)
learn.opt_fn=optim.Adam
learn.crit=mask_loss
learn.metrics=[mask_acc]

# %%
learn.load('0')

# %%
learn.lr_find()
learn.sched.plot()
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
#   5%|▍         | 12/255 [00:10<03:28,  1.17it/s, loss=-13.1]

# %%
lr=4e-2

# %%
learn.fit(lr,1,cycle_len=5,use_clr=(20,5))
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=5), HTML(value='')))
#   3%|▎         | 8/255 [00:09<04:43,  1.15s/it, loss=-15.9]
# Exception in thread Thread-130:
# Traceback (most recent call last):
#   File "/home/paperspace/anaconda3/envs/fastai/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/home/paperspace/anaconda3/envs/fastai/lib/python3.6/site-packages/tqdm/_tqdm.py", line 144, in run
#     for instance in self.tqdm_cls._instances:
#   File "/home/paperspace/anaconda3/envs/fastai/lib/python3.6/_weakrefset.py", line 60, in __iter__
#     for itemref in self.data:
# RuntimeError: Set changed size during iteration
#  97%|█████████▋| 248/255 [02:51<00:04,  1.44it/s, loss=-3.35e+04]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-326-d2f0b97a920e> in <module>()
# ----> 1 learn.fit(lr,1,cycle_len=5,use_clr=(20,5))
#
# ~/fastai/courses/dl2/fastai/learner.py in fit(self, lrs, n_cycle, wds, **kwargs)
#     212         self.sched = None
#     213         layer_opt = self.get_layer_opt(lrs, wds)
# --> 214         return self.fit_gen(self.model, self.data, layer_opt, n_cycle, **kwargs)
#     215
#     216     def warm_up(self, lr, wds=None):
#
# ~/fastai/courses/dl2/fastai/learner.py in fit_gen(self, model, data, layer_opt, n_cycle, cycle_len, cycle_mult, cycle_save_name, best_save_name, use_clr, metrics, callbacks, use_wd_sched, norm_wds, wds_sched_mult, **kwargs)
#     159         n_epoch = sum_geom(cycle_len if cycle_len else 1, cycle_mult, n_cycle)
#     160         return fit(model, data, n_epoch, layer_opt.opt, self.crit,
# --> 161             metrics=metrics, callbacks=callbacks, reg_fn=self.reg_fn, clip=self.clip, **kwargs)
#     162
#     163     def get_layer_groups(self): return self.models.get_layer_groups()
#
# ~/fastai/courses/dl2/fastai/model.py in fit(model, data, epochs, opt, crit, metrics, callbacks, stepper, **kwargs)
#      94             batch_num += 1
#      95             for cb in callbacks: cb.on_batch_begin()
# ---> 96             loss = stepper.step(V(x),V(y), epoch)
#      97             avg_loss = avg_loss * avg_mom + loss * (1-avg_mom)
#      98             debias_loss = avg_loss / (1 - avg_mom**batch_num)
#
# ~/fastai/courses/dl2/fastai/model.py in step(self, xs, y, epoch)
#      47             nn.utils.clip_grad_norm(trainable_params_(self.m), self.clip)
#      48         self.opt.step()
# ---> 49         return raw_loss.data[0]
#      50
#      51     def evaluate(self, xs, y):
#
# KeyboardInterrupt:

# %%
learn.save('vgg-tmp')

# %%
learn.load('vgg-tmp')

# %%
learn.unfreeze()
learn.bn_freeze(True)

# %%
lrs = np.array([lr/100,lr/10,lr])/4

# %%
learn.fit(lrs,1,cycle_len=8,use_clr=(20,8))

# %%
learn.save('vgg-512')

# %%
x,y = next(iter(md.val_dl))
py = to_np(learn.model(V(x)))

# %%
ax = show_img(denorm(x)[0])
show_img(py[0][0]>0, ax=ax, alpha=0.5);

# %%
ax = show_img(denorm(x)[0])
show_img(y[0,...,-1], ax=ax, alpha=0.5);

# %% [markdown]
# ## 1024x1024

# %%
sz = 1024
bs = 4

# %%
tfms = tfms_from_model(vgg16, sz, crop_type=CropType.NO, tfm_y=TfmType.PIXEL, aug_tfms=aug_tfms)
datasets = ImageData.get_ds(MatchedFilesDataset, (trn_x,trn_y), (val_x,val_y), tfms, path=PATH)
md = ImageData(PATH, datasets, bs, num_workers=4, classes=None)

# %%
denorm = md.trn_ds.denorm
x,y = next(iter(md.aug_dl))
x = denorm(x)

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 10))
for i,ax in enumerate(axes.flat):
    ax=show_img(x[i], ax=ax)
    show_img(y[i][...,0], ax=ax, alpha=0.5)
plt.tight_layout(pad=0.1)

# %%
simple_up = nn.Sequential(
    nn.ReLU(),
    StdUpsample(512,256),
    StdUpsample(256,256),
    StdUpsample(256,256),
    StdUpsample(256,256),
    nn.ConvTranspose2d(256, 1, 2, stride=2),
)

# %%
models = ConvnetBuilder(vgg16, 0, 0, 0, custom_head=simple_up)
learn = ConvLearner(md, models)
learn.opt_fn=optim.Adam
learn.crit=mask_loss
learn.metrics=[mask_acc]

# %%
learn.load('512')

# %%
learn.lr_find()
learn.sched.plot()

# %%
lr=4e-2

# %%
learn.fit(lr,1,cycle_len=2,use_clr=(20,4))

# %%
learn.save('vgg-tmp')

# %%
learn.load('vgg-tmp')

# %%
learn.unfreeze()
learn.bn_freeze(True)

# %%
lrs = np.array([lr/100,lr/10,lr])/8

# %%
learn.fit(lrs,1,cycle_len=4,use_clr=(20,8))

# %%
learn.fit(lrs,1,cycle_len=40,use_clr=(20,10))

# %%
learn.save('1024')

# %%
x,y = next(iter(md.val_dl))
py = to_np(learn.model(V(x)))

# %%
ax = show_img(denorm(x)[0])
show_img(py[0][0]>0, ax=ax, alpha=0.5);

# %%
ax = show_img(denorm(x)[0])
show_img(y[0,...,-1], ax=ax, alpha=0.5);

# %%
show_img(py[0][0]>0);

# %%
show_img(y[0,...,-1]);

# %% [markdown]
# ## Fin

# %%
x,y = next(iter(md.val_dl))

# %%
py = to_np(learn.model(V(x)))

# %%
ax = show_img(denorm(x)[0])
show_img(py[0][0]>0, ax=ax, alpha=0.5);

# %%
ax = show_img(denorm(x)[0])
